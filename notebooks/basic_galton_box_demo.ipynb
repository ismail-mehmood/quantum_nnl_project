# %% [markdown]
# Basic Quantum Galton Board Examples:
#
# We can input a number of photons and a board depth to the function sample_basic_board() to simulate and return a plot of the binning outcomes.

# %%
import os

# %%
os.chdir("..")

# %% [markdown]
# The above is a slightly nasty hack to set the working directory one higher, i.e work from the repo route. This ideally would not exist, clever solution incoming.

# %%
print(os.getcwd())
# Out:
# /home/ismail/quantum_python/quantum_nnl_project

# %%
from src.basic_galton_box import sample_basic_board

# %%
sample_basic_board(5, 100)

# %% [markdown]
# The above plot is showing constructive and destructive interference in the paths that the photons are taking down the board. We can see clearly that destructive interference occurs in bins 4 and 6, as well as...
